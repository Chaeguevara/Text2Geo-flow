# %%
import osmnx as ox
import matplotlib.pyplot as plt

# %%
place_name = "Sinsa-dong,gwanak-gu,seoul, korea"
graph = ox.graph_from_place(place_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d7/wr0_38q17_38rmx4dysxdyfh0000gn/T/ipykernel_2055/806874358.py in <module>
#       1 place_name = "Sinsa-dong, seoul, korea"
# ----> 2 graph = ox.graph_from_place("https://www.openstreetmap.org/api/0.6/relation/5598056")
#
# ~/opt/anaconda3/envs/textToGeo/lib/python3.7/site-packages/osmnx/graph.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, buffer_dist, clean_periphery, custom_filter)
#     328         # then it is a single place
#     329         gdf_place = geocoder.geocode_to_gdf(
# --> 330             query, which_result=which_result, buffer_dist=buffer_dist
#     331         )
#     332     elif isinstance(query, list):
#
# ~/opt/anaconda3/envs/textToGeo/lib/python3.7/site-packages/osmnx/geocoder.py in geocode_to_gdf(query, which_result, by_osmid, buffer_dist)
#     108     gdf = gpd.GeoDataFrame()
#     109     for q, wr in zip(query, which_result):
# --> 110         gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
#     111
#     112     # reset GeoDataFrame index and set its CRS
#
# ~/opt/anaconda3/envs/textToGeo/lib/python3.7/site-packages/osmnx/geocoder.py in _geocode_query_to_gdf(query, which_result, by_osmid)
#     156     if not results:
#     157         # if no results were returned, raise error
# --> 158         raise ValueError(f'Nominatim geocoder returned 0 results for query "{query}"')
#     159
#     160     elif by_osmid:
#
# ValueError: Nominatim geocoder returned 0 results for query "https://www.openstreetmap.org/api/0.6/relation/5598056"

# %%
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
fig, ax = ox.plot_graph(graph)

# %%
nodes, edges = ox.graph_to_gdfs(graph)
nodes.head()
# Out:
#                    y           x  street_count highway  \
# osmid
# 436861531  37.522355  127.033408             4     NaN
# 450612916  37.519060  127.022467             4     NaN
# 450614641  37.519908  127.026291             3     NaN
# 450615564  37.521556  127.023551             5     NaN
# 450615565  37.523230  127.023276             3     NaN
#
#                              geometry
# osmid
# 436861531  POINT (127.03341 37.52236)
# 450612916  POINT (127.02247 37.51906)
# 450614641  POINT (127.02629 37.51991)
# 450615564  POINT (127.02355 37.52156)
# 450615565  POINT (127.02328 37.52323)

# %%
area = ox.geocode_to_gdf(place_name)
type(area)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
area
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((127.00838 37.52588, 127.01318 ...   37.529649   37.516002
#
#     bbox_east   bbox_west   place_id  osm_type   osm_id        lat  \
# 0  127.040735  127.008376  298844867  relation  5598056  37.522321
#
#           lon                                display_name     class  \
# 0  127.027694  Sinsa-dong, Gangnam-gu, Seoul, South Korea  boundary
#
#              type  importance
# 0  administrative    0.693504

# %%
area.plot()
# Out:
# <AxesSubplot:>
